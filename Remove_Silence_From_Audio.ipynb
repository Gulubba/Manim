# %%
#@title Run Gradio App
# %cd /content/
# !git clone https://github.com/NeuralFalconYT/Remove-Silence-From-Audio.git
# %cd Remove-Silence-From-Audio
# !pip install -r requirements.txt
from IPython.display import clear_output
clear_output()
# !python app.py --share --debug
# Out:
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to /root/.cache/torch/hub/master.zip
# Silero VAD model loaded successfully!
# /content/Remove-Silence-From-Audio/app.py:504: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(
# /content/Remove-Silence-From-Audio/app.py:504: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
